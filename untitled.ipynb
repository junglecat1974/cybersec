# %%
import socket

# %%
server_socket=socket.socket()

# %%
type (server_socket)
# Out:
# socket.socket

# %%
metodi=dir (server_socket)

# %%
type (metodi)
# Out:
# list

# %%
for metodo in metodi:
    print (metodo)

# %%
for metodo in metodi:
    if not metodo.startswith('_'):
                  print (metodo)

# %%
def dirOnly(istanza):
    methods=dir(istanza)    
    for m in methods:
        if not m.startswith('_'):
                    print (m)

# %%
dirOnly('sdfsdf')

# %%
def dirOnly(istanza):
    methods=dir(istanza)
    risultato=[]    
    for m in methods:
        if not m.startswith('_'):
                    print (m)

# %%
dirOnly([])

# %%
def dirOnly(istanza):
    methods=dir(istanza)
    risultato=[]    
    for m in methods:
        if not m.startswith('_'):
                    risultato.append(m)
    return(risultato)

# %%
dirOnly([])

# %%
dir('ciao')

# %%
help(socket)
